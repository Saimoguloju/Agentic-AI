# %%
from langchain_community.document_loaders import PyPDFLoader
loader=PyPDFLoader('AI-ML Engineer.pdf')
docs = loader.load()
docs
# Out:
# [Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-06-11T07:29:28+00:00', 'title': 'Purple and White Clean and Professional Resume', 'moddate': '2025-06-11T07:29:23+00:00', 'keywords': 'DAGYOkhUO6o,BAE97iXIB2I,0', 'author': 'Moguloju Sai', 'source': 'AI-ML Engineer.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}, page_content='Moguloju Sai\nWORK EXPERIENCE\nEDUCATION\n Sep 2020 - Oct 2024\nJr Data Scientist Intern at Coapps.ai\nDeveloped a Retrieval-Augmented Generation (RAG) application using OpenAI language models and\nOpenAI embeddings for intelligent PDF document processing.\nEngineered AI-driven summarization and semantic query-based retrieval workflows for enhanced content\nunderstanding.\nBuilt a user-friendly Streamlit web application for interactive document exploration and Q&A.\nApplied modular software design principles to ensure code reusability and scalability.\nDeployed the solution using Docker and hosted the project on Hugging Face Spaces for public access\nand demonstration.\nMar 2024 - May 2024\nBachelor of Technology in Data Science\nTKR College of Engineering and Technology\nSpecialization in Data Science.\nHyderabad, Telangana • +91 9398053071 • saimoguloju2@gmail.com \n LinkedIn, GitHub, YouTube\nTECHNICAL SKILLS\nProgramming Skills: Java, R, Python, MySQL\nTools & Platforms: git, GitHub, Excel, Tableau, AWS, PowerBI, Dockers, Motion, Cursor AI\nFrameworks: Streamlit, Flask, NLTK, FAISS db, vertex ai, Pinecone, Pydantic, FastAPI\nMachine Learning, Deep Learning, Natural Language Processing,\nGenerative AI: Fine Tuning LLMs, RAG, Langchain,  Hugging Face\nModels: Chatgpt, geminiai, Llama, Deep Seek, Claude, Ollama \nAgentic AI: Langgraph, n8n, Agno, MCP, crewai\nData Scientist Intern at Layc Education Pvt Ltd July 2024 - Jan 2025\nDeveloped a Fake News Detection system using Natural Language Processing (NLP) and machine\nlearning, achieving 92% prediction accuracy.\nApplied NLP preprocessing techniques, including stemming, on a dataset of 10,000+ news articles.\nBuilt and deployed a user-facing Streamlit web application for real-time fake news classification.\nUtilized traditional machine learning models for text classification and deployed the solution on\nHugging Face for public access.\nAI Engineer Intern at Helios Core AI Feb 2025 - Present\nDeveloped AI-powered microservices using FastAPI to deliver intelligent solutions through scalable REST\nAPIs.\nBuilt and integrated LLM-based features, including conversational AI workflows leveraging OpenAI and\nLangChain.\nDesigned document summarization pipelines supporting multiple file formats (PDF, DOCX, TXT).\nIntegrated Azure Cognitive Services to enable speech-to-text and text-to-speech functionalities.\nImplemented secure file handling and retrieval using Azure Blob Storage.\nContributed to session management and backend data modeling using Pydantic.\nApplied SOLID principles along with unit and integration testing.\nAssisted in cloud deployment with Docker, Uvicorn, and Gunicorn, including SSL configuration for secure\naccess.\nSUMMARY\nAI Engineer Intern with 1 year of hands-on experience, contributing to diverse AI and backend development\nprojects. Currently working at Helios Core AI, focusing on developing scalable backend systems and\nintegrating AI-driven solutions. Proven ability to design, build, and deploy machine learning pipelines and\nAPIs in real-world applications.'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-06-11T07:29:28+00:00', 'title': 'Purple and White Clean and Professional Resume', 'moddate': '2025-06-11T07:29:23+00:00', 'keywords': 'DAGYOkhUO6o,BAE97iXIB2I,0', 'author': 'Moguloju Sai', 'source': 'AI-ML Engineer.pdf', 'total_pages': 2, 'page': 1, 'page_label': '2'}, page_content='Completed AWS Fundamentals certification on Coursera and Data Science with Python certification\nfrom NPTEL.\nRegularly publish articles on Medium and LinkedIn, engaging a professional audience with 11K+ LinkedIn\nfollowers.\nBuilding a thriving Telugu Data Science Community by sharing knowledge across Twitter, WhatsApp\nchannel, and YouTube. \nADDITIONAL INFORMATION\nDeveloped a web app for real-time fake news detection using Python and Streamlit. Preprocessed text\nwith stemming and TF-IDF, training a Logistic Regression model with an 80-20 split for high accuracy.\n   GitHub Fake News Detection using NLP                                                         \nDeveloped a Flask-based English-to-Telugu translator with user authentication using MySQL.\nIntegrated LangChain with Groq API and Modular Coding format, tested with Postman.\nImplemented secure user login, registration, and session management for personalized access.\nEnglish to Telugu Translator using Generative AI                                                           GitHub \nPROJECTS')]

# %%
## Recursive splitter
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(chunk_size=100,chunk_overlap=50)
final_documents = text_splitter.split_documents(docs)
final_documents
# Out:
# [Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-06-11T07:29:28+00:00', 'title': 'Purple and White Clean and Professional Resume', 'moddate': '2025-06-11T07:29:23+00:00', 'keywords': 'DAGYOkhUO6o,BAE97iXIB2I,0', 'author': 'Moguloju Sai', 'source': 'AI-ML Engineer.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}, page_content='Moguloju Sai\nWORK EXPERIENCE\nEDUCATION\n Sep 2020 - Oct 2024\nJr Data Scientist Intern at Coapps.ai'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-06-11T07:29:28+00:00', 'title': 'Purple and White Clean and Professional Resume', 'moddate': '2025-06-11T07:29:23+00:00', 'keywords': 'DAGYOkhUO6o,BAE97iXIB2I,0', 'author': 'Moguloju Sai', 'source': 'AI-ML Engineer.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}, page_content='Developed a Retrieval-Augmented Generation (RAG) application using OpenAI language models and'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-06-11T07:29:28+00:00', 'title': 'Purple and White Clean and Professional Resume', 'moddate': '2025-06-11T07:29:23+00:00', 'keywords': 'DAGYOkhUO6o,BAE97iXIB2I,0', 'author': 'Moguloju Sai', 'source': 'AI-ML Engineer.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}, page_content='OpenAI embeddings for intelligent PDF document processing.'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-06-11T07:29:28+00:00', 'title': 'Purple and White Clean and Professional Resume', 'moddate': '2025-06-11T07:29:23+00:00', 'keywords': 'DAGYOkhUO6o,BAE97iXIB2I,0', 'author': 'Moguloju Sai', 'source': 'AI-ML Engineer.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}, page_content='Engineered AI-driven summarization and semantic query-based retrieval workflows for enhanced'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-06-11T07:29:28+00:00', 'title': 'Purple and White Clean and Professional Resume', 'moddate': '2025-06-11T07:29:23+00:00', 'keywords': 'DAGYOkhUO6o,BAE97iXIB2I,0', 'author': 'Moguloju Sai', 'source': 'AI-ML Engineer.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}, page_content='query-based retrieval workflows for enhanced content'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-06-11T07:29:28+00:00', 'title': 'Purple and White Clean and Professional Resume', 'moddate': '2025-06-11T07:29:23+00:00', 'keywords': 'DAGYOkhUO6o,BAE97iXIB2I,0', 'author': 'Moguloju Sai', 'source': 'AI-ML Engineer.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}, page_content='understanding.'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-06-11T07:29:28+00:00', 'title': 'Purple and White Clean and Professional Resume', 'moddate': '2025-06-11T07:29:23+00:00', 'keywords': 'DAGYOkhUO6o,BAE97iXIB2I,0', 'author': 'Moguloju Sai', 'source': 'AI-ML Engineer.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}, page_content='Built a user-friendly Streamlit web application for interactive document exploration and Q&A.'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-06-11T07:29:28+00:00', 'title': 'Purple and White Clean and Professional Resume', 'moddate': '2025-06-11T07:29:23+00:00', 'keywords': 'DAGYOkhUO6o,BAE97iXIB2I,0', 'author': 'Moguloju Sai', 'source': 'AI-ML Engineer.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}, page_content='Applied modular software design principles to ensure code reusability and scalability.'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-06-11T07:29:28+00:00', 'title': 'Purple and White Clean and Professional Resume', 'moddate': '2025-06-11T07:29:23+00:00', 'keywords': 'DAGYOkhUO6o,BAE97iXIB2I,0', 'author': 'Moguloju Sai', 'source': 'AI-ML Engineer.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}, page_content='Deployed the solution using Docker and hosted the project on Hugging Face Spaces for public access'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-06-11T07:29:28+00:00', 'title': 'Purple and White Clean and Professional Resume', 'moddate': '2025-06-11T07:29:23+00:00', 'keywords': 'DAGYOkhUO6o,BAE97iXIB2I,0', 'author': 'Moguloju Sai', 'source': 'AI-ML Engineer.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}, page_content='and demonstration.\nMar 2024 - May 2024\nBachelor of Technology in Data Science'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-06-11T07:29:28+00:00', 'title': 'Purple and White Clean and Professional Resume', 'moddate': '2025-06-11T07:29:23+00:00', 'keywords': 'DAGYOkhUO6o,BAE97iXIB2I,0', 'author': 'Moguloju Sai', 'source': 'AI-ML Engineer.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}, page_content='Bachelor of Technology in Data Science\nTKR College of Engineering and Technology'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-06-11T07:29:28+00:00', 'title': 'Purple and White Clean and Professional Resume', 'moddate': '2025-06-11T07:29:23+00:00', 'keywords': 'DAGYOkhUO6o,BAE97iXIB2I,0', 'author': 'Moguloju Sai', 'source': 'AI-ML Engineer.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}, page_content='TKR College of Engineering and Technology\nSpecialization in Data Science.'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-06-11T07:29:28+00:00', 'title': 'Purple and White Clean and Professional Resume', 'moddate': '2025-06-11T07:29:23+00:00', 'keywords': 'DAGYOkhUO6o,BAE97iXIB2I,0', 'author': 'Moguloju Sai', 'source': 'AI-ML Engineer.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}, page_content='Specialization in Data Science.\nHyderabad, Telangana • +91 9398053071 • saimoguloju2@gmail.com'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-06-11T07:29:28+00:00', 'title': 'Purple and White Clean and Professional Resume', 'moddate': '2025-06-11T07:29:23+00:00', 'keywords': 'DAGYOkhUO6o,BAE97iXIB2I,0', 'author': 'Moguloju Sai', 'source': 'AI-ML Engineer.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}, page_content='LinkedIn, GitHub, YouTube\nTECHNICAL SKILLS\nProgramming Skills: Java, R, Python, MySQL'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-06-11T07:29:28+00:00', 'title': 'Purple and White Clean and Professional Resume', 'moddate': '2025-06-11T07:29:23+00:00', 'keywords': 'DAGYOkhUO6o,BAE97iXIB2I,0', 'author': 'Moguloju Sai', 'source': 'AI-ML Engineer.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}, page_content='Tools & Platforms: git, GitHub, Excel, Tableau, AWS, PowerBI, Dockers, Motion, Cursor AI'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-06-11T07:29:28+00:00', 'title': 'Purple and White Clean and Professional Resume', 'moddate': '2025-06-11T07:29:23+00:00', 'keywords': 'DAGYOkhUO6o,BAE97iXIB2I,0', 'author': 'Moguloju Sai', 'source': 'AI-ML Engineer.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}, page_content='Frameworks: Streamlit, Flask, NLTK, FAISS db, vertex ai, Pinecone, Pydantic, FastAPI'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-06-11T07:29:28+00:00', 'title': 'Purple and White Clean and Professional Resume', 'moddate': '2025-06-11T07:29:23+00:00', 'keywords': 'DAGYOkhUO6o,BAE97iXIB2I,0', 'author': 'Moguloju Sai', 'source': 'AI-ML Engineer.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}, page_content='Machine Learning, Deep Learning, Natural Language Processing,'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-06-11T07:29:28+00:00', 'title': 'Purple and White Clean and Professional Resume', 'moddate': '2025-06-11T07:29:23+00:00', 'keywords': 'DAGYOkhUO6o,BAE97iXIB2I,0', 'author': 'Moguloju Sai', 'source': 'AI-ML Engineer.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}, page_content='Generative AI: Fine Tuning LLMs, RAG, Langchain,  Hugging Face'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-06-11T07:29:28+00:00', 'title': 'Purple and White Clean and Professional Resume', 'moddate': '2025-06-11T07:29:23+00:00', 'keywords': 'DAGYOkhUO6o,BAE97iXIB2I,0', 'author': 'Moguloju Sai', 'source': 'AI-ML Engineer.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}, page_content='Models: Chatgpt, geminiai, Llama, Deep Seek, Claude, Ollama'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-06-11T07:29:28+00:00', 'title': 'Purple and White Clean and Professional Resume', 'moddate': '2025-06-11T07:29:23+00:00', 'keywords': 'DAGYOkhUO6o,BAE97iXIB2I,0', 'author': 'Moguloju Sai', 'source': 'AI-ML Engineer.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}, page_content='Agentic AI: Langgraph, n8n, Agno, MCP, crewai'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-06-11T07:29:28+00:00', 'title': 'Purple and White Clean and Professional Resume', 'moddate': '2025-06-11T07:29:23+00:00', 'keywords': 'DAGYOkhUO6o,BAE97iXIB2I,0', 'author': 'Moguloju Sai', 'source': 'AI-ML Engineer.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}, page_content='Data Scientist Intern at Layc Education Pvt Ltd July 2024 - Jan 2025'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-06-11T07:29:28+00:00', 'title': 'Purple and White Clean and Professional Resume', 'moddate': '2025-06-11T07:29:23+00:00', 'keywords': 'DAGYOkhUO6o,BAE97iXIB2I,0', 'author': 'Moguloju Sai', 'source': 'AI-ML Engineer.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}, page_content='Developed a Fake News Detection system using Natural Language Processing (NLP) and machine'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-06-11T07:29:28+00:00', 'title': 'Purple and White Clean and Professional Resume', 'moddate': '2025-06-11T07:29:23+00:00', 'keywords': 'DAGYOkhUO6o,BAE97iXIB2I,0', 'author': 'Moguloju Sai', 'source': 'AI-ML Engineer.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}, page_content='learning, achieving 92% prediction accuracy.'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-06-11T07:29:28+00:00', 'title': 'Purple and White Clean and Professional Resume', 'moddate': '2025-06-11T07:29:23+00:00', 'keywords': 'DAGYOkhUO6o,BAE97iXIB2I,0', 'author': 'Moguloju Sai', 'source': 'AI-ML Engineer.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}, page_content='Applied NLP preprocessing techniques, including stemming, on a dataset of 10,000+ news articles.'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-06-11T07:29:28+00:00', 'title': 'Purple and White Clean and Professional Resume', 'moddate': '2025-06-11T07:29:23+00:00', 'keywords': 'DAGYOkhUO6o,BAE97iXIB2I,0', 'author': 'Moguloju Sai', 'source': 'AI-ML Engineer.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}, page_content='Built and deployed a user-facing Streamlit web application for real-time fake news classification.'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-06-11T07:29:28+00:00', 'title': 'Purple and White Clean and Professional Resume', 'moddate': '2025-06-11T07:29:23+00:00', 'keywords': 'DAGYOkhUO6o,BAE97iXIB2I,0', 'author': 'Moguloju Sai', 'source': 'AI-ML Engineer.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}, page_content='Utilized traditional machine learning models for text classification and deployed the solution on'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-06-11T07:29:28+00:00', 'title': 'Purple and White Clean and Professional Resume', 'moddate': '2025-06-11T07:29:23+00:00', 'keywords': 'DAGYOkhUO6o,BAE97iXIB2I,0', 'author': 'Moguloju Sai', 'source': 'AI-ML Engineer.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}, page_content='Hugging Face for public access.\nAI Engineer Intern at Helios Core AI Feb 2025 - Present'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-06-11T07:29:28+00:00', 'title': 'Purple and White Clean and Professional Resume', 'moddate': '2025-06-11T07:29:23+00:00', 'keywords': 'DAGYOkhUO6o,BAE97iXIB2I,0', 'author': 'Moguloju Sai', 'source': 'AI-ML Engineer.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}, page_content='Developed AI-powered microservices using FastAPI to deliver intelligent solutions through scalable'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-06-11T07:29:28+00:00', 'title': 'Purple and White Clean and Professional Resume', 'moddate': '2025-06-11T07:29:23+00:00', 'keywords': 'DAGYOkhUO6o,BAE97iXIB2I,0', 'author': 'Moguloju Sai', 'source': 'AI-ML Engineer.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}, page_content='to deliver intelligent solutions through scalable REST'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-06-11T07:29:28+00:00', 'title': 'Purple and White Clean and Professional Resume', 'moddate': '2025-06-11T07:29:23+00:00', 'keywords': 'DAGYOkhUO6o,BAE97iXIB2I,0', 'author': 'Moguloju Sai', 'source': 'AI-ML Engineer.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}, page_content='APIs.'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-06-11T07:29:28+00:00', 'title': 'Purple and White Clean and Professional Resume', 'moddate': '2025-06-11T07:29:23+00:00', 'keywords': 'DAGYOkhUO6o,BAE97iXIB2I,0', 'author': 'Moguloju Sai', 'source': 'AI-ML Engineer.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}, page_content='Built and integrated LLM-based features, including conversational AI workflows leveraging OpenAI'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-06-11T07:29:28+00:00', 'title': 'Purple and White Clean and Professional Resume', 'moddate': '2025-06-11T07:29:23+00:00', 'keywords': 'DAGYOkhUO6o,BAE97iXIB2I,0', 'author': 'Moguloju Sai', 'source': 'AI-ML Engineer.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}, page_content='conversational AI workflows leveraging OpenAI and'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-06-11T07:29:28+00:00', 'title': 'Purple and White Clean and Professional Resume', 'moddate': '2025-06-11T07:29:23+00:00', 'keywords': 'DAGYOkhUO6o,BAE97iXIB2I,0', 'author': 'Moguloju Sai', 'source': 'AI-ML Engineer.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}, page_content='LangChain.'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-06-11T07:29:28+00:00', 'title': 'Purple and White Clean and Professional Resume', 'moddate': '2025-06-11T07:29:23+00:00', 'keywords': 'DAGYOkhUO6o,BAE97iXIB2I,0', 'author': 'Moguloju Sai', 'source': 'AI-ML Engineer.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}, page_content='Designed document summarization pipelines supporting multiple file formats (PDF, DOCX, TXT).'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-06-11T07:29:28+00:00', 'title': 'Purple and White Clean and Professional Resume', 'moddate': '2025-06-11T07:29:23+00:00', 'keywords': 'DAGYOkhUO6o,BAE97iXIB2I,0', 'author': 'Moguloju Sai', 'source': 'AI-ML Engineer.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}, page_content='Integrated Azure Cognitive Services to enable speech-to-text and text-to-speech functionalities.'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-06-11T07:29:28+00:00', 'title': 'Purple and White Clean and Professional Resume', 'moddate': '2025-06-11T07:29:23+00:00', 'keywords': 'DAGYOkhUO6o,BAE97iXIB2I,0', 'author': 'Moguloju Sai', 'source': 'AI-ML Engineer.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}, page_content='Implemented secure file handling and retrieval using Azure Blob Storage.'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-06-11T07:29:28+00:00', 'title': 'Purple and White Clean and Professional Resume', 'moddate': '2025-06-11T07:29:23+00:00', 'keywords': 'DAGYOkhUO6o,BAE97iXIB2I,0', 'author': 'Moguloju Sai', 'source': 'AI-ML Engineer.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}, page_content='Contributed to session management and backend data modeling using Pydantic.'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-06-11T07:29:28+00:00', 'title': 'Purple and White Clean and Professional Resume', 'moddate': '2025-06-11T07:29:23+00:00', 'keywords': 'DAGYOkhUO6o,BAE97iXIB2I,0', 'author': 'Moguloju Sai', 'source': 'AI-ML Engineer.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}, page_content='Applied SOLID principles along with unit and integration testing.'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-06-11T07:29:28+00:00', 'title': 'Purple and White Clean and Professional Resume', 'moddate': '2025-06-11T07:29:23+00:00', 'keywords': 'DAGYOkhUO6o,BAE97iXIB2I,0', 'author': 'Moguloju Sai', 'source': 'AI-ML Engineer.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}, page_content='Assisted in cloud deployment with Docker, Uvicorn, and Gunicorn, including SSL configuration for'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-06-11T07:29:28+00:00', 'title': 'Purple and White Clean and Professional Resume', 'moddate': '2025-06-11T07:29:23+00:00', 'keywords': 'DAGYOkhUO6o,BAE97iXIB2I,0', 'author': 'Moguloju Sai', 'source': 'AI-ML Engineer.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}, page_content='and Gunicorn, including SSL configuration for secure'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-06-11T07:29:28+00:00', 'title': 'Purple and White Clean and Professional Resume', 'moddate': '2025-06-11T07:29:23+00:00', 'keywords': 'DAGYOkhUO6o,BAE97iXIB2I,0', 'author': 'Moguloju Sai', 'source': 'AI-ML Engineer.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}, page_content='access.\nSUMMARY'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-06-11T07:29:28+00:00', 'title': 'Purple and White Clean and Professional Resume', 'moddate': '2025-06-11T07:29:23+00:00', 'keywords': 'DAGYOkhUO6o,BAE97iXIB2I,0', 'author': 'Moguloju Sai', 'source': 'AI-ML Engineer.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}, page_content='AI Engineer Intern with 1 year of hands-on experience, contributing to diverse AI and backend'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-06-11T07:29:28+00:00', 'title': 'Purple and White Clean and Professional Resume', 'moddate': '2025-06-11T07:29:23+00:00', 'keywords': 'DAGYOkhUO6o,BAE97iXIB2I,0', 'author': 'Moguloju Sai', 'source': 'AI-ML Engineer.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}, page_content='contributing to diverse AI and backend development'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-06-11T07:29:28+00:00', 'title': 'Purple and White Clean and Professional Resume', 'moddate': '2025-06-11T07:29:23+00:00', 'keywords': 'DAGYOkhUO6o,BAE97iXIB2I,0', 'author': 'Moguloju Sai', 'source': 'AI-ML Engineer.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}, page_content='projects. Currently working at Helios Core AI, focusing on developing scalable backend systems and'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-06-11T07:29:28+00:00', 'title': 'Purple and White Clean and Professional Resume', 'moddate': '2025-06-11T07:29:23+00:00', 'keywords': 'DAGYOkhUO6o,BAE97iXIB2I,0', 'author': 'Moguloju Sai', 'source': 'AI-ML Engineer.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}, page_content='integrating AI-driven solutions. Proven ability to design, build, and deploy machine learning'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-06-11T07:29:28+00:00', 'title': 'Purple and White Clean and Professional Resume', 'moddate': '2025-06-11T07:29:23+00:00', 'keywords': 'DAGYOkhUO6o,BAE97iXIB2I,0', 'author': 'Moguloju Sai', 'source': 'AI-ML Engineer.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}, page_content='to design, build, and deploy machine learning pipelines and'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-06-11T07:29:28+00:00', 'title': 'Purple and White Clean and Professional Resume', 'moddate': '2025-06-11T07:29:23+00:00', 'keywords': 'DAGYOkhUO6o,BAE97iXIB2I,0', 'author': 'Moguloju Sai', 'source': 'AI-ML Engineer.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}, page_content='APIs in real-world applications.'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-06-11T07:29:28+00:00', 'title': 'Purple and White Clean and Professional Resume', 'moddate': '2025-06-11T07:29:23+00:00', 'keywords': 'DAGYOkhUO6o,BAE97iXIB2I,0', 'author': 'Moguloju Sai', 'source': 'AI-ML Engineer.pdf', 'total_pages': 2, 'page': 1, 'page_label': '2'}, page_content='Completed AWS Fundamentals certification on Coursera and Data Science with Python certification'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-06-11T07:29:28+00:00', 'title': 'Purple and White Clean and Professional Resume', 'moddate': '2025-06-11T07:29:23+00:00', 'keywords': 'DAGYOkhUO6o,BAE97iXIB2I,0', 'author': 'Moguloju Sai', 'source': 'AI-ML Engineer.pdf', 'total_pages': 2, 'page': 1, 'page_label': '2'}, page_content='from NPTEL.'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-06-11T07:29:28+00:00', 'title': 'Purple and White Clean and Professional Resume', 'moddate': '2025-06-11T07:29:23+00:00', 'keywords': 'DAGYOkhUO6o,BAE97iXIB2I,0', 'author': 'Moguloju Sai', 'source': 'AI-ML Engineer.pdf', 'total_pages': 2, 'page': 1, 'page_label': '2'}, page_content='Regularly publish articles on Medium and LinkedIn, engaging a professional audience with 11K+'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-06-11T07:29:28+00:00', 'title': 'Purple and White Clean and Professional Resume', 'moddate': '2025-06-11T07:29:23+00:00', 'keywords': 'DAGYOkhUO6o,BAE97iXIB2I,0', 'author': 'Moguloju Sai', 'source': 'AI-ML Engineer.pdf', 'total_pages': 2, 'page': 1, 'page_label': '2'}, page_content='engaging a professional audience with 11K+ LinkedIn'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-06-11T07:29:28+00:00', 'title': 'Purple and White Clean and Professional Resume', 'moddate': '2025-06-11T07:29:23+00:00', 'keywords': 'DAGYOkhUO6o,BAE97iXIB2I,0', 'author': 'Moguloju Sai', 'source': 'AI-ML Engineer.pdf', 'total_pages': 2, 'page': 1, 'page_label': '2'}, page_content='followers.'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-06-11T07:29:28+00:00', 'title': 'Purple and White Clean and Professional Resume', 'moddate': '2025-06-11T07:29:23+00:00', 'keywords': 'DAGYOkhUO6o,BAE97iXIB2I,0', 'author': 'Moguloju Sai', 'source': 'AI-ML Engineer.pdf', 'total_pages': 2, 'page': 1, 'page_label': '2'}, page_content='Building a thriving Telugu Data Science Community by sharing knowledge across Twitter, WhatsApp'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-06-11T07:29:28+00:00', 'title': 'Purple and White Clean and Professional Resume', 'moddate': '2025-06-11T07:29:23+00:00', 'keywords': 'DAGYOkhUO6o,BAE97iXIB2I,0', 'author': 'Moguloju Sai', 'source': 'AI-ML Engineer.pdf', 'total_pages': 2, 'page': 1, 'page_label': '2'}, page_content='channel, and YouTube. \nADDITIONAL INFORMATION'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-06-11T07:29:28+00:00', 'title': 'Purple and White Clean and Professional Resume', 'moddate': '2025-06-11T07:29:23+00:00', 'keywords': 'DAGYOkhUO6o,BAE97iXIB2I,0', 'author': 'Moguloju Sai', 'source': 'AI-ML Engineer.pdf', 'total_pages': 2, 'page': 1, 'page_label': '2'}, page_content='Developed a web app for real-time fake news detection using Python and Streamlit. Preprocessed text'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-06-11T07:29:28+00:00', 'title': 'Purple and White Clean and Professional Resume', 'moddate': '2025-06-11T07:29:23+00:00', 'keywords': 'DAGYOkhUO6o,BAE97iXIB2I,0', 'author': 'Moguloju Sai', 'source': 'AI-ML Engineer.pdf', 'total_pages': 2, 'page': 1, 'page_label': '2'}, page_content='with stemming and TF-IDF, training a Logistic Regression model with an 80-20 split for high'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-06-11T07:29:28+00:00', 'title': 'Purple and White Clean and Professional Resume', 'moddate': '2025-06-11T07:29:23+00:00', 'keywords': 'DAGYOkhUO6o,BAE97iXIB2I,0', 'author': 'Moguloju Sai', 'source': 'AI-ML Engineer.pdf', 'total_pages': 2, 'page': 1, 'page_label': '2'}, page_content='Regression model with an 80-20 split for high accuracy.'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-06-11T07:29:28+00:00', 'title': 'Purple and White Clean and Professional Resume', 'moddate': '2025-06-11T07:29:23+00:00', 'keywords': 'DAGYOkhUO6o,BAE97iXIB2I,0', 'author': 'Moguloju Sai', 'source': 'AI-ML Engineer.pdf', 'total_pages': 2, 'page': 1, 'page_label': '2'}, page_content='GitHub Fake News Detection using NLP'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-06-11T07:29:28+00:00', 'title': 'Purple and White Clean and Professional Resume', 'moddate': '2025-06-11T07:29:23+00:00', 'keywords': 'DAGYOkhUO6o,BAE97iXIB2I,0', 'author': 'Moguloju Sai', 'source': 'AI-ML Engineer.pdf', 'total_pages': 2, 'page': 1, 'page_label': '2'}, page_content='Developed a Flask-based English-to-Telugu translator with user authentication using MySQL.'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-06-11T07:29:28+00:00', 'title': 'Purple and White Clean and Professional Resume', 'moddate': '2025-06-11T07:29:23+00:00', 'keywords': 'DAGYOkhUO6o,BAE97iXIB2I,0', 'author': 'Moguloju Sai', 'source': 'AI-ML Engineer.pdf', 'total_pages': 2, 'page': 1, 'page_label': '2'}, page_content='Integrated LangChain with Groq API and Modular Coding format, tested with Postman.'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-06-11T07:29:28+00:00', 'title': 'Purple and White Clean and Professional Resume', 'moddate': '2025-06-11T07:29:23+00:00', 'keywords': 'DAGYOkhUO6o,BAE97iXIB2I,0', 'author': 'Moguloju Sai', 'source': 'AI-ML Engineer.pdf', 'total_pages': 2, 'page': 1, 'page_label': '2'}, page_content='Implemented secure user login, registration, and session management for personalized access.'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-06-11T07:29:28+00:00', 'title': 'Purple and White Clean and Professional Resume', 'moddate': '2025-06-11T07:29:23+00:00', 'keywords': 'DAGYOkhUO6o,BAE97iXIB2I,0', 'author': 'Moguloju Sai', 'source': 'AI-ML Engineer.pdf', 'total_pages': 2, 'page': 1, 'page_label': '2'}, page_content='English to Telugu Translator using Generative AI'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-06-11T07:29:28+00:00', 'title': 'Purple and White Clean and Professional Resume', 'moddate': '2025-06-11T07:29:23+00:00', 'keywords': 'DAGYOkhUO6o,BAE97iXIB2I,0', 'author': 'Moguloju Sai', 'source': 'AI-ML Engineer.pdf', 'total_pages': 2, 'page': 1, 'page_label': '2'}, page_content='GitHub'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-06-11T07:29:28+00:00', 'title': 'Purple and White Clean and Professional Resume', 'moddate': '2025-06-11T07:29:23+00:00', 'keywords': 'DAGYOkhUO6o,BAE97iXIB2I,0', 'author': 'Moguloju Sai', 'source': 'AI-ML Engineer.pdf', 'total_pages': 2, 'page': 1, 'page_label': '2'}, page_content='PROJECTS')]

# %%
print(final_documents[0])
print(final_documents[1])
# Out:
# page_content='Moguloju Sai
# WORK EXPERIENCE
# EDUCATION
#  Sep 2020 - Oct 2024
# Jr Data Scientist Intern at Coapps.ai' metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-06-11T07:29:28+00:00', 'title': 'Purple and White Clean and Professional Resume', 'moddate': '2025-06-11T07:29:23+00:00', 'keywords': 'DAGYOkhUO6o,BAE97iXIB2I,0', 'author': 'Moguloju Sai', 'source': 'AI-ML Engineer.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}
# page_content='Developed a Retrieval-Augmented Generation (RAG) application using OpenAI language models and' metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-06-11T07:29:28+00:00', 'title': 'Purple and White Clean and Professional Resume', 'moddate': '2025-06-11T07:29:23+00:00', 'keywords': 'DAGYOkhUO6o,BAE97iXIB2I,0', 'author': 'Moguloju Sai', 'source': 'AI-ML Engineer.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}

# %%
from langchain_community.document_loaders import TextLoader

loader=TextLoader('test.txt')
docs=loader.load()
docs
# Out:
# [Document(metadata={'source': 'test.txt'}, page_content="Ghattamaneni Mahesh Babu (born 9 August 1975) is an Indian actor, producer and philanthropist who works in Telugu cinema. He is one of the highest-paid actors in Indian cinema and has featured in Forbes India's Celebrity 100 list since 2012.[1][2] He has appeared in over 25 films and is a recipient of several accolades including, nine Nandi Awards, two Gaddar Telangana Film Awards, five Filmfare Awards South and four SIIMA Awards.\n\nThe younger son of veteran Telugu actor Krishna, Mahesh Babu made his debut as a child artist in a cameo role in a Telugu film called Needa (1979), at the age of four. He went on to act as a child artist in the films Sankharavam (1987), Bazaar Rowdy, Mugguru Kodukulu (both 1988) and Gudachari 117 (1989). He played a dual role in the film Koduku Diddina Kapuram (1989). Babu then appeared in Balachandrudu and Anna Thammudu (both 1990). He made his debut as a lead actor with Rajakumarudu (1999) which won him the Nandi Award for Best Male Debut.")]

# %%
text = ""
with open('test.txt') as f:
    text=f.read()
    
text_splitter=RecursiveCharacterTextSplitter(chunk_size=100,chunk_overlap=20)
text=text_splitter.create_documents(text)
print(text)
# Out:
# [Document(metadata={}, page_content='G'), Document(metadata={}, page_content='h'), Document(metadata={}, page_content='a'), Document(metadata={}, page_content='t'), Document(metadata={}, page_content='t'), Document(metadata={}, page_content='a'), Document(metadata={}, page_content='m'), Document(metadata={}, page_content='a'), Document(metadata={}, page_content='n'), Document(metadata={}, page_content='e'), Document(metadata={}, page_content='n'), Document(metadata={}, page_content='i'), Document(metadata={}, page_content='M'), Document(metadata={}, page_content='a'), Document(metadata={}, page_content='h'), Document(metadata={}, page_content='e'), Document(metadata={}, page_content='s'), Document(metadata={}, page_content='h'), Document(metadata={}, page_content='B'), Document(metadata={}, page_content='a'), Document(metadata={}, page_content='b'), Document(metadata={}, page_content='u'), Document(metadata={}, page_content='('), Document(metadata={}, page_content='b'), Document(metadata={}, page_content='o'), Document(metadata={}, page_content='r'), Document(metadata={}, page_content='n'), Document(metadata={}, page_content='9'), Document(metadata={}, page_content='A'), Document(metadata={}, page_content='u'), Document(metadata={}, page_content='g'), Document(metadata={}, page_content='u'), Document(metadata={}, page_content='s'), Document(metadata={}, page_content='t'), Document(metadata={}, page_content='1'), Document(metadata={}, page_content='9'), Document(metadata={}, page_content='7'), Document(metadata={}, page_content='5'), Document(metadata={}, page_content=')'), Document(metadata={}, page_content='i'), Document(metadata={}, page_content='s'), Document(metadata={}, page_content='a'), Document(metadata={}, page_content='n'), Document(metadata={}, page_content='I'), Document(metadata={}, page_content='n'), Document(metadata={}, page_content='d'), Document(metadata={}, page_content='i'), Document(metadata={}, page_content='a'), Document(metadata={}, page_content='n'), Document(metadata={}, page_content='a'), Document(metadata={}, page_content='c'), Document(metadata={}, page_content='t'), Document(metadata={}, page_content='o'), Document(metadata={}, page_content='r'), Document(metadata={}, page_content=','), Document(metadata={}, page_content='p'), Document(metadata={}, page_content='r'), Document(metadata={}, page_content='o'), Document(metadata={}, page_content='d'), Document(metadata={}, page_content='u'), Document(metadata={}, page_content='c'), Document(metadata={}, page_content='e'), Document(metadata={}, page_content='r'), Document(metadata={}, page_content='a'), Document(metadata={}, page_content='n'), Document(metadata={}, page_content='d'), Document(metadata={}, page_content='p'), Document(metadata={}, page_content='h'), Document(metadata={}, page_content='i'), Document(metadata={}, page_content='l'), Document(metadata={}, page_content='a'), Document(metadata={}, page_content='n'), Document(metadata={}, page_content='t'), Document(metadata={}, page_content='h'), Document(metadata={}, page_content='r'), Document(metadata={}, page_content='o'), Document(metadata={}, page_content='p'), Document(metadata={}, page_content='i'), Document(metadata={}, page_content='s'), Document(metadata={}, page_content='t'), Document(metadata={}, page_content='w'), Document(metadata={}, page_content='h'), Document(metadata={}, page_content='o'), Document(metadata={}, page_content='w'), Document(metadata={}, page_content='o'), Document(metadata={}, page_content='r'), Document(metadata={}, page_content='k'), Document(metadata={}, page_content='s'), Document(metadata={}, page_content='i'), Document(metadata={}, page_content='n'), Document(metadata={}, page_content='T'), Document(metadata={}, page_content='e'), Document(metadata={}, page_content='l'), Document(metadata={}, page_content='u'), Document(metadata={}, page_content='g'), Document(metadata={}, page_content='u'), Document(metadata={}, page_content='c'), Document(metadata={},  ...

# %%
docs
# Out:
# [Document(metadata={'source': 'test.txt'}, page_content="Ghattamaneni Mahesh Babu (born 9 August 1975) is an Indian actor, producer and philanthropist who works in Telugu cinema. He is one of the highest-paid actors in Indian cinema and has featured in Forbes India's Celebrity 100 list since 2012.[1][2] He has appeared in over 25 films and is a recipient of several accolades including, nine Nandi Awards, two Gaddar Telangana Film Awards, five Filmfare Awards South and four SIIMA Awards.\n\nThe younger son of veteran Telugu actor Krishna, Mahesh Babu made his debut as a child artist in a cameo role in a Telugu film called Needa (1979), at the age of four. He went on to act as a child artist in the films Sankharavam (1987), Bazaar Rowdy, Mugguru Kodukulu (both 1988) and Gudachari 117 (1989). He played a dual role in the film Koduku Diddina Kapuram (1989). Babu then appeared in Balachandrudu and Anna Thammudu (both 1990). He made his debut as a lead actor with Rajakumarudu (1999) which won him the Nandi Award for Best Male Debut.")]

# %%
## Character Text Splitter

from langchain_text_splitters import CharacterTextSplitter
text_splitter=CharacterTextSplitter(separator='\n\n',chunk_size=100,chunk_overlap=20)
text_splitter.split_documents(docs)
# Out:
# Created a chunk of size 434, which is longer than the specified 100
# [Document(metadata={'source': 'test.txt'}, page_content="Ghattamaneni Mahesh Babu (born 9 August 1975) is an Indian actor, producer and philanthropist who works in Telugu cinema. He is one of the highest-paid actors in Indian cinema and has featured in Forbes India's Celebrity 100 list since 2012.[1][2] He has appeared in over 25 films and is a recipient of several accolades including, nine Nandi Awards, two Gaddar Telangana Film Awards, five Filmfare Awards South and four SIIMA Awards."),
#  Document(metadata={'source': 'test.txt'}, page_content='The younger son of veteran Telugu actor Krishna, Mahesh Babu made his debut as a child artist in a cameo role in a Telugu film called Needa (1979), at the age of four. He went on to act as a child artist in the films Sankharavam (1987), Bazaar Rowdy, Mugguru Kodukulu (both 1988) and Gudachari 117 (1989). He played a dual role in the film Koduku Diddina Kapuram (1989). Babu then appeared in Balachandrudu and Anna Thammudu (both 1990). He made his debut as a lead actor with Rajakumarudu (1999) which won him the Nandi Award for Best Male Debut.')]
