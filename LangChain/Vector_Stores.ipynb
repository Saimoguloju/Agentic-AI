# %% [markdown]
# ### Faiss db

# %%
from langchain_community.document_loaders import TextLoader
from langchain_community.vectorstores import FAISS
from langchain_ollama import OllamaEmbeddings
from langchain_text_splitters import CharacterTextSplitter

# %%
loader = TextLoader("test.txt")
documents=loader.load()
text_splitter=CharacterTextSplitter(chunk_size=200,chunk_overlap=30)
docs = text_splitter.split_documents(documents)
# Out:
# Created a chunk of size 434, which is longer than the specified 200

# %%
docs
# Out:
# [Document(metadata={'source': 'test.txt'}, page_content="Ghattamaneni Mahesh Babu (born 9 August 1975) is an Indian actor, producer and philanthropist who works in Telugu cinema. He is one of the highest-paid actors in Indian cinema and has featured in Forbes India's Celebrity 100 list since 2012.[1][2] He has appeared in over 25 films and is a recipient of several accolades including, nine Nandi Awards, two Gaddar Telangana Film Awards, five Filmfare Awards South and four SIIMA Awards."),
#  Document(metadata={'source': 'test.txt'}, page_content='The younger son of veteran Telugu actor Krishna, Mahesh Babu made his debut as a child artist in a cameo role in a Telugu film called Needa (1979), at the age of four. He went on to act as a child artist in the films Sankharavam (1987), Bazaar Rowdy, Mugguru Kodukulu (both 1988) and Gudachari 117 (1989). He played a dual role in the film Koduku Diddina Kapuram (1989). Babu then appeared in Balachandrudu and Anna Thammudu (both 1990). He made his debut as a lead actor with Rajakumarudu (1999) which won him the Nandi Award for Best Male Debut.')]

# %%
embeddings = OllamaEmbeddings(model='llama3.2')
db=FAISS.from_documents(docs,embeddings)
db

# %%
query="Mahesh Babu"
docs = db.similarity_search(query)
docs
# Out:
# [Document(id='54c02e1f-55b4-4975-9ff4-5da1fa9fd1f1', metadata={'source': 'test.txt'}, page_content='The younger son of veteran Telugu actor Krishna, Mahesh Babu made his debut as a child artist in a cameo role in a Telugu film called Needa (1979), at the age of four. He went on to act as a child artist in the films Sankharavam (1987), Bazaar Rowdy, Mugguru Kodukulu (both 1988) and Gudachari 117 (1989). He played a dual role in the film Koduku Diddina Kapuram (1989). Babu then appeared in Balachandrudu and Anna Thammudu (both 1990). He made his debut as a lead actor with Rajakumarudu (1999) which won him the Nandi Award for Best Male Debut.'),
#  Document(id='37fc0556-d1ea-4ad1-944c-7ee19d7cd224', metadata={'source': 'test.txt'}, page_content="Ghattamaneni Mahesh Babu (born 9 August 1975) is an Indian actor, producer and philanthropist who works in Telugu cinema. He is one of the highest-paid actors in Indian cinema and has featured in Forbes India's Celebrity 100 list since 2012.[1][2] He has appeared in over 25 films and is a recipient of several accolades including, nine Nandi Awards, two Gaddar Telangana Film Awards, five Filmfare Awards South and four SIIMA Awards.")]

# %%
retriever = db.as_retriever()
docs=retriever.invoke(query)
docs[0].page_content
# Out:
# 'The younger son of veteran Telugu actor Krishna, Mahesh Babu made his debut as a child artist in a cameo role in a Telugu film called Needa (1979), at the age of four. He went on to act as a child artist in the films Sankharavam (1987), Bazaar Rowdy, Mugguru Kodukulu (both 1988) and Gudachari 117 (1989). He played a dual role in the film Koduku Diddina Kapuram (1989). Babu then appeared in Balachandrudu and Anna Thammudu (both 1990). He made his debut as a lead actor with Rajakumarudu (1999) which won him the Nandi Award for Best Male Debut.'

# %%
docs_and_score = db.similarity_search_with_score(query)
docs_and_score
# Out:
# [(Document(id='54c02e1f-55b4-4975-9ff4-5da1fa9fd1f1', metadata={'source': 'test.txt'}, page_content='The younger son of veteran Telugu actor Krishna, Mahesh Babu made his debut as a child artist in a cameo role in a Telugu film called Needa (1979), at the age of four. He went on to act as a child artist in the films Sankharavam (1987), Bazaar Rowdy, Mugguru Kodukulu (both 1988) and Gudachari 117 (1989). He played a dual role in the film Koduku Diddina Kapuram (1989). Babu then appeared in Balachandrudu and Anna Thammudu (both 1990). He made his debut as a lead actor with Rajakumarudu (1999) which won him the Nandi Award for Best Male Debut.'),
#   np.float32(1.1814274)),
#  (Document(id='37fc0556-d1ea-4ad1-944c-7ee19d7cd224', metadata={'source': 'test.txt'}, page_content="Ghattamaneni Mahesh Babu (born 9 August 1975) is an Indian actor, producer and philanthropist who works in Telugu cinema. He is one of the highest-paid actors in Indian cinema and has featured in Forbes India's Celebrity 100 list since 2012.[1][2] He has appeared in over 25 films and is a recipient of several accolades including, nine Nandi Awards, two Gaddar Telangana Film Awards, five Filmfare Awards South and four SIIMA Awards."),
#   np.float32(1.3285282))]

# %%
embedding_vector = embeddings.embed_query(query)
embedding_vector
# Out:
# [-0.010089716,
#  -0.006832084,
#  0.0019513112,
#  -0.00039344621,
#  -0.004522946,
#  -0.019556575,
#  -0.010628074,
#  0.017521217,
#  0.02813654,
#  -0.017357241,
#  -0.022181917,
#  -0.002962401,
#  0.002480111,
#  0.048862908,
#  -0.010526905,
#  0.026638402,
#  0.0044906097,
#  0.018865583,
#  0.00046534083,
#  0.010405418,
#  -0.01358767,
#  -0.012978451,
#  -0.025614474,
#  0.0043664007,
#  0.006697435,
#  -0.009246423,
#  0.010132972,
#  -0.054182716,
#  0.0116380425,
#  -0.010155425,
#  0.024532998,
#  0.009312962,
#  -0.0012898981,
#  0.007590741,
#  -0.0050528827,
#  -0.003247138,
#  -0.0009437343,
#  0.02065731,
#  0.0027005225,
#  0.020052938,
#  0.004202825,
#  0.014359651,
#  0.0024001165,
#  -0.004541942,
#  0.018401375,
#  0.011607606,
#  -0.03747933,
#  0.00955171,
#  -0.00057344744,
#  0.012684644,
#  -0.0033502996,
#  -0.0048564123,
#  0.0002848711,
#  0.0047097146,
#  0.010956462,
#  -0.006088888,
#  0.03380929,
#  -0.011432781,
#  -0.02129912,
#  -0.0040322454,
#  0.0068011815,
#  -0.0182855,
#  -0.017784549,
#  -0.0020469863,
#  -0.005357191,
#  -0.004824929,
#  -0.0003107081,
#  0.0029952128,
#  -0.0070438017,
#  -0.0023157706,
#  0.008369227,
#  0.010678469,
#  0.0041152732,
#  -0.005863786,
#  0.0004660983,
#  0.009499962,
#  -0.0035154426,
#  0.012299542,
#  -0.0067801187,
#  -0.016893143,
#  -0.016961252,
#  -0.032798413,
#  0.009564955,
#  -0.0060131843,
#  0.0046830154,
#  0.014584358,
#  0.020742742,
#  0.0022819857,
#  -0.032082565,
#  0.010500624,
#  0.017039688,
#  -0.022427896,
#  -0.011103958,
#  -0.00018969807,
#  0.021411657,
#  0.015317773,
#  -0.03110039,
#  0.004576415,
#  0.0017897238,
#  -0.010596434,
#  0.004708758,
#  0.004974598,
#  -0.002584285,
#  0.01608603,
#  -0.0064423974,
#  0.0023047351,
#  0.033020053,
#  0.020860134,
#  0.0009121092,
#  0.0041006585,
#  0.010909387,
#  0.008766882,
#  0.021640973,
#  -0.020602122,
#  0.0017945197,
#  0.0062464727,
#  0.011595336,
#  0.0037274528,
#  -0.009515703,
#  -0.017360564,
#  -0.016210273,
#  -0.007671652,
#  0.014266857,
#  -0.009909892,
#  0.009342024,
#  -0.00232833,
#  -0.0073421067,
#  -0.0033267818,
#  0.025437867,
#  -0.0068732235,
#  -0.0033655942,
#  -0.00084823876,
#  0.008672132,
#  -0.0014783278,
#  0.011837581,
#  -0.002453701,
#  0.012062928,
#  0.007873731,
#  -0.013661288,
#  -0.012629769,
#  0.012765694,
#  0.0010989625,
#  0.023283584,
#  0.018966403,
#  0.0033321406,
#  0.026384866,
#  0.0043457826,
#  -0.00046889466,
#  -0.010509098,
#  -0.015673889,
#  -0.013802314,
#  -0.002421247,
#  0.015419722,
#  0.012981312,
#  -0.0031050858,
#  -0.016865725,
#  0.04321806,
#  -0.022543916,
#  0.009140449,
#  0.0030240077,
#  -0.010224725,
#  0.013639101,
#  0.024435153,
#  -0.024574297,
#  0.0047344402,
#  0.0073749223,
#  0.0066939886,
#  -0.014366213,
#  -0.0052765617,
#  0.016909005,
#  0.018356992,
#  -0.016860062,
#  -0.00093661476,
#  -0.011939359,
#  0.0075017773,
#  0.016462218,
#  0.0012961834,
#  -0.007824471,
#  -0.015353776,
#  -0.00687122,
#  -0.009726293,
#  0.025611628,
#  0.032365493,
#  -0.04663328,
#  0.007773232,
#  0.005086329,
#  -0.0064677214,
#  0.0045456705,
#  -0.001274487,
#  0.008119953,
#  -0.00018157445,
#  0.005181951,
#  -0.045845546,
#  -0.007615104,
#  0.008485799,
#  -0.036742244,
#  0.0036630153,
#  0.051819146,
#  -0.010667029,
#  0.016482279,
#  -0.0019526932,
#  -0.025228798,
#  -0.03079053,
#  -0.017238209,
#  -0.003767658,
#  0.0052792854,
#  0.022781532,
#  0.011960955,
#  0.014834904,
#  -0.012951998,
#  -0.00067566294,
#  0.0030508493,
#  -0.0048008743,
#  0.022961969,
#  -0.005543715,
#  -0.03376865,
#  0.013828153,
#  0.009968726,
#  0.0023833474,
#  0.0013652937,
#  0.0036312114,
#  0.0008206876,
#  0.023575922,
#  0.0066960435,
#  -0.012186074,
#  -0.029247995,
#  0.0054439274,
#  -0.0016853655,
#  -0.006028705,
#  0.005997151,
#  -0.0043918407,
#  -0.01809503,
#  -0.041825972,
#  0.0074205524,
#  0.010211779,
#  -0.011406776,
#  -0.00329039,
#  0.008663043,
#  -0.00353788,
#  0.0006312992,
#  -0.007906206,
#  -0.009418238,
#  0.027344003,
#  0.022859663,
#  -0.010814121,
#  0.026451923,
#  0.027686428,
#  -0.011490974,
#  -0.008554159,
#  0.011504364,
#  0.027457425,
#  -0.020208688,
#  -0.020541323,
#  0.0036316754,
#  0.0030158404,
#  -0.01752374,
#  -0.048526477,
#  -0.003957096,
#  -0.012074598,
#  0.016133916,
#  0.02999008,
#  0.0072362553,
#  -0.014058427,
#  0.00846335,
#  -0.012300312,
#  -0.020492366,
#  -0.0041137477,
#  -0.019549742,
#  -0.008040405,
#  -0.012885992,
#  -0.00021167626,
#  0.01901648,
#  -0.015841747,
#  -0.016275018,
#  0.011527962,
#  -0.031790927,
#  0.019027129,
#  -0.0058107767,
#  -0.00965502,
#  0.030061487,
#  -0.0013816092,
#  -0.007037041,
#  -0.05379467,
#  -0.00041268257,
#  -0.021030668,
#  0.0041948734,
#  0.0028529093,
#  0.012288597,
#  0.0054345634,
#  0.013399007,
#  0.0017866472,
#  0.012020737,
#  0.006544673,
#  -0.010489341,
#  -0.010200698,
#  -0.005067466,
#  -0.009695459,
#  0.026040077,
#  -0.002780614,
#  0.010644319,
#  0.00033918855,
#  -0.016238322,
#  -0.0021153495,
#  0.01056525,
#  0.031193726,
#  0.0020434682,
#  0.010760572,
#  0.00044597068,
#  0.020404574,
#  -0.053782143,
#  0.022174064,
#  -0.015207247,
#  0.011249104,
#  0.012538996,
#  -0.015663872,
#  0.0015764309,
#  -0.0030766807,
#  -0.012442272,
#  -0.005233266,
#  -0.014007171,
#  0.01673064,
#  -0.009430997,
#  0.0040845093,
#  -0.007022202,
#  -0.02673184,
#  0.017265249,
#  -0.011124266,
#  -0.015396483,
#  0.013916185,
#  -0.0059508304,
#  -0.0045727426,
#  0.007043766,
#  0.02168094,
#  0.0047822883,
#  -0.02863028,
#  0.021233547,
#  -0.007645411,
#  -0.0041630217,
#  -0.0012699808,
#  0.0023536405,
#  0.012546156,
#  0.004119927,
#  -0.012109485,
#  0.015213284,
#  0.010540244,
#  -0.01998458,
#  -0.024788717,
#  -0.01744428,
#  0.016002245,
#  0.010177478,
#  0.035650015,
#  -0.01837513,
#  0.02229667,
#  -0.02263953,
#  -0.010415775,
#  -0.005979168,
#  -0.001450279,
#  0.011765727,
#  0.005364207,
#  -0.0071077663,
#  -0.014073359,
#  0.007779394,
#  -0.01756057,
#  -0.0075187976,
#  0.08465303,
#  -0.020902662,
#  0.015541885,
#  -0.021708503,
#  -0.0010809212,
#  0.004468989,
#  0.047343146,
#  -0.019979326,
#  0.02147258,
#  -0.016712748,
#  -0.0031469148,
#  -0.0194652,
#  -0.008449226,
#  0.025978977,
#  0.0019776013,
#  0.006805083,
#  0.007988158,
#  -0.029631406,
#  -0.035706945,
#  -0.01922905,
#  0.022780525,
#  -0.00815868,
#  -0.018687366,
#  0.008877754,
#  -0.029154321,
#  0.00017368214,
#  0.005710874,
#  0.04087219,
#  3.766144e-05,
#  0.0030802651,
#  0.0039252974,
#  -0.007932345,
#  -0.0022804313,
#  -0.00014185281,
#  -0.027986584,
#  0.007787012,
#  0.025597125,
#  -0.0074337767,
#  -0.012564121,
#  -0.0041455985,
#  -0.0026165205,
#  -0.008848273,
#  -0.035382498,
#  0.023697577,
#  0.007822916,
#  -0.0106558325,
#  -0.008364345,
#  0.03498741,
#  -0.000991591,
#  0.008542772,
#  -0.020575386,
#  -0.022789411,
#  0.005762599,
#  0.022828354,
#  0.015343694,
#  -0.017385313,
#  0.013716226,
#  0.01657104,
#  0.0052989116,
#  -0.004906795,
#  0.018412193,
#  -0.008009587,
#  0.026075462,
#  0.0070759477,
#  -0.01701056,
#  0.006573616,
#  0.014638945,
#  -0.022068601,
#  -0.0052849,
#  -0.0065663373,
#  -0.025872644,
#  0.005531421,
#  -0.026085354,
#  -0.022204414,
#  0.008640155,
#  -0.012994334,
#  0.020298395,
#  0.022697141,
#  -0.0066153943,
#  -0.028295333,
#  0.0026251124,
#  -0.004628958,
#  0.021108508,
#  -0.011588409,
#  0.014944425,
#  -0.014436583,
#  0.011919171,
#  -0.030434009,
#  -0.004000348,
#  0.0044508846,
#  0.02375003,
#  0.013486659,
#  -0.0031374816,
#  -0.006632234,
#  -0.005020025,
#  0.03686024,
#  -0.015816338,
#  -0.012065499,
#  -0.005363319,
#  -0.0005789195,
#  -0.0002800625,
#  0.014646563,
#  -0.011913353,
#  0.010391657,
#  0.010351144,
#  0.025315678,
#  -0.022853877,
#  0.030981643,
#  0.0013217939,
#  -0.0064821243,
#  0.008914522,
#  -0.0024791292,
#  0.028408667,
#  0.0104133375,
#  0.008972248,
#  -0.016075617,
#  0.029464388,
#  0.017144617,
#  0.0052958135,
#  -0.0048442376,
#  0.016247932,
#  -0.0065847533,
#  -0.0064159217,
#  -0.009770426,
#  0.0024766272,
#  0.034072958,
#  0.0034165399,
#  0.01697824,
#  -0.0067860964,
#  0.015565487,
#  0.0099955145,
#  0.013649036,
#  0.014180004,
#  -0.009833889,
#  -0.039634958,
#  0.0005744407,
#  0.008673069,
#  -0.026193075,
#  -3.215711e-05,
#  -0.025517492,
#  0.015483853,
#  -0.010351769,
#  0.026434863,
#  -0.01600408,
#  -0.0026647414,
#  0.0085751405,
#  0.011770035,
#  0.0123311775,
#  -0.008006698,
#  -0.02771113,
#  0.014913911,
#  -0.026601432,
#  0.018109955,
#  0.009146165,
#  0.0010755686,
#  0.0071051503,
#  0.023290342,
#  -0.021636387,
#  -0.0027594494,
#  0.030855535,
#  0.0012399026,
#  -0.01999498,
#  0.02867293,
#  0.01893028,
#  0.0026516502,
#  0.0016929155,
#  -0.0036141125,
#  0.021741202,
#  0.010713619,
#  0.013897085,
#  0.004917009,
#  0.02417931,
#  0.02506166,
#  0.012755816,
#  0.0043195435,
#  0.0030773731,
#  0.01668617,
#  0.00013146807,
#  0.0021431819,
#  0.038321897,
#  0.022827199,
#  0.016062874,
#  -0.027434764,
#  -0.0045200298,
#  0.028324403,
#  0.008985425,
#  -0.0015471899,
#  0.0130634485,
#  0.0006079269,
#  -0.018649979,
#  -0.009486628,
#  0.020441469,
#  -0.005189606,
#  -0.00035530125,
#  0.027183292,
#  0.0031208268,
#  -0.004585137,
#  0.012132045,
#  0.029427916,
#  -0.013376428,
#  -0.025906065,
#  -0.0458947,
#  0.0069666575,
#  0.0042598424,
#  -0.026253175,
#  0.004925569,
#  -0.011898491,
#  -0.012281562,
#  -0.0007410698,
#  -0.0035296723,
#  -0.0045527183,
#  -0.0112670455,
#  0.0035705105,
#  0.009672568,
#  0.005337016,
#  0.0011781278,
#  -0.011709068,
#  0.002336061,
#  0.012176879,
#  -0.020701302,
#  0.0076680947,
#  0.00029373728,
#  -0.0031316874,
#  0.010290928,
#  0.0039144442,
#  -0.0015404274,
#  -0.002299521,
#  -0.003916487,
#  0.01786599,
#  0.009088184,
#  0.0052771852,
#  0.009175473,
#  0.0047154194,
#  -0.030032301,
#  -0.0072994493,
#  0.015376587,
#  -0.01826635,
#  0.025658255,
#  0.0077268314,
#  0.01728467,
#  0.0011743909,
#  -0.011086154,
#  -0.012343415,
#  -0.021343622,
#  0.010299893,
#  -0.033550717,
#  -0.0013725176,
#  0.010543149,
#  -0.011787667,
#  -0.018625792,
#  0.0006095695,
#  0.017736822,
#  0.001129522,
#  -0.022893248,
#  -0.0067199664,
#  -0.011560417,
#  -0.026449,
#  -0.019751856,
#  0.011038412,
#  0.005399922,
#  -0.016579593,
#  -0.013627985,
#  -0.019921098,
#  -0.021995695,
#  0.0028551356,
#  -0.009407115,
#  -0.03332211,
#  0.01002011,
#  -0.011131203,
#  -0.006167434,
#  0.033658713,
#  0.0054134633,
#  -0.018214874,
#  -0.0025715702,
#  -0.010164044,
#  0.009032888,
#  0.027506402,
#  0.008036,
#  -0.04219987,
#  -0.025580432,
#  0.00822579,
#  -0.0035269991,
#  0.0071918294,
#  0.03014987,
#  0.026421253,
#  -0.008491144,
#  -0.005058649,
#  0.0042264066,
#  0.020870907,
#  -0.030955946,
#  -0.026764289,
#  -0.013596248,
#  -0.0017879446,
#  -0.00312856,
#  0.0012728734,
#  -0.0030788344,
#  0.008916971,
#  0.012488613,
#  -0.013130886,
#  0.005791089,
#  0.005626511,
#  0.008980373,
#  0.0008921934,
#  -0.0182456,
#  -0.012688275,
#  -0.021811837,
#  0.024923766,
#  -0.020017615,
#  -0.018420268,
#  0.017322162,
#  -0.009184764,
#  0.013180615,
#  0.03264032,
#  0.0015482081,
#  -0.019842371,
#  -0.0146166915,
#  0.00086859334,
#  -0.002508289,
#  -0.013214871,
#  -0.021067398,
#  -0.0018150975,
#  -0.01151422,
#  0.01694991,
#  0.009416741,
#  -0.0012310783,
#  -0.01872441,
#  -0.013322333,
#  -0.012369968,
#  0.001839633,
#  0.0035213782,
#  -0.022761397,
#  0.0038445187,
#  -0.026364919,
#  -0.020926332,
#  0.009282806,
#  -0.007851989,
#  -0.005530126,
#  -0.00892063,
#  0.016111124,
#  2.0316513e-05,
#  -0.011414265,
#  -0.031727567,
#  0.011120221,
#  0.0010229461,
#  -0.010580737,
#  0.0391848,
#  -0.025541252,
#  0.022049047,
#  -0.013393645,
#  -0.0005700672,
#  0.003785971,
#  -0.009698345,
#  0.0062313536,
#  0.0059233312,
#  -0.007359666,
#  0.015860239,
#  0.005075205,
#  0.0061396756,
#  -0.0024488256,
#  -0.017800806,
#  -0.009443695,
#  0.004920675,
#  -0.018181663,
#  -0.03072423,
#  -0.0057527367,
#  0.0054484755,
#  -0.011617013,
#  -0.010006536,
#  0.004375227,
#  0.01126644,
#  -0.03330629,
#  -0.0019766989,
#  -0.004294368,
#  0.011693742,
#  -0.031017613,
#  -0.011776717,
#  0.0064346762,
#  0.021638032,
#  0.0029765938,
#  0.0044049895,
#  -0.0016213018,
#  0.009196025,
#  0.00965273,
#  0.0016206542,
#  0.0036819417,
#  0.012613331,
#  -0.030575687,
#  0.02468226,
#  -0.015848767,
#  -0.022170248,
#  -0.030495701,
#  -0.035988707,
#  -0.0075190803,
#  0.0030913819,
#  0.015561471,
#  0.016702924,
#  -0.011251066,
#  0.0009498886,
#  -0.00743738,
#  0.009400192,
#  0.0037373288,
#  -0.022712143,
#  0.011641892,
#  -0.013047317,
#  -0.04019888,
#  0.006237692,
#  0.013758543,
#  0.0005392345,
#  -0.010312866,
#  -0.024872072,
#  -0.017510053,
#  -0.009882591,
#  -0.01947642,
#  -0.035102244,
#  -0.017394204,
#  -0.013920325,
#  0.0034407591,
#  -0.01637985,
#  -0.008083839,
#  0.014902616,
#  0.006579866,
#  -0.017747689,
#  0.009956344,
#  -0.0032142783,
#  -0.00081961235,
#  -0.005618129,
#  0.0022168197,
#  -0.023288108,
#  -0.008782251,
#  0.00862627,
#  0.023453707,
#  0.001984974,
#  0.0061564515,
#  0.0151969325,
#  0.010194164,
#  -0.011274738,
#  -0.043770805,
#  -0.021211185,
#  0.0018696827,
#  0.016880952,
#  -0.009595338,
#  -0.026129896,
#  0.01079639,
#  -0.011098853,
#  0.03112094,
#  0.010600328,
#  0.016615871,
#  -0.010625452,
#  0.017741563,
#  -0.024968708,
#  0.0044384054,
#  -0.031939533,
#  -0.020018056,
#  0.008579297,
#  0.0035885726,
#  0.018583868,
#  0.023782063,
#  0.017046576,
#  0.00070907566,
#  -0.017904552,
#  -0.0093525145,
#  0.016586313,
#  -0.025056403,
#  0.018540516,
#  1.9822783e-05,
#  0.016458051,
#  -0.005253847,
#  -0.034552786,
#  0.026378814,
#  0.017386004,
#  -0.009291927,
#  -0.027313534,
#  0.01038181,
#  0.005141924,
#  -0.00410408,
#  -0.0011013752,
#  -0.0028139139,
#  0.010908911,
#  0.0032374635,
#  -0.00571897,
#  0.009116144,
#  0.025242535,
#  0.019718504,
#  -0.004061634,
#  0.011177495,
#  0.012424068,
#  -0.022636577,
#  -0.022105286,
#  0.005027666,
#  0.024112698,
#  0.025175244,
#  0.011542507,
#  -0.0047991024,
#  0.023153016,
#  0.022317387,
#  -0.026165329,
#  0.023461588,
#  -0.015445438,
#  0.0006158476,
#  -0.05172008,
#  -0.0010689499,
#  0.006144756,
#  0.005549,
#  0.011252414,
#  -0.024833487,
#  0.012570514,
#  -0.031780947,
#  -0.019109806,
#  0.0277481,
#  0.004062404,
#  -0.0055188825,
#  -0.013866049,
#  -0.02794447,
#  0.0112927,
#  -0.0038148724,
#  0.003651815,
#  -0.0073951567,
#  0.016268615,
#  -0.005760932,
#  -0.02558736,
#  0.006878808,
#  -0.012648675,
#  0.022750236,
#  -0.007133055,
#  0.01746922,
#  -0.012254398,
#  -0.005050141,
#  -0.0009819013,
#  -0.0029424091,
#  -0.0005237384,
#  -0.013394871,
#  -0.009642829,
#  -0.0030884128,
#  0.041277044,
#  0.0375702,
#  -0.012787429,
#  -0.022501001,
#  -0.00015711236,
#  -0.023201227,
#  0.0063737063,
#  0.013851245,
#  -0.0015198267,
#  -0.011049931,
#  -0.010120099,
#  0.011442433,
#  0.0021950237,
#  -9.896763e-05,
#  -0.005968665,
#  0.01731752,
#  -0.0018777143,
#  0.02778872,
#  -0.0054872776,
#  0.007370795,
#  -0.0026178577,
#  -0.008145971,
#  -0.019166619,
#  -0.016044542,
#  -0.027823593,
#  -0.019915393,
#  0.014739277,
#  -0.02427328,
#  -0.01934067,
#  -0.045071382,
#  -0.0071552447,
#  0.06064097,
#  -0.013345889,
#  -0.015812634,
#  0.006367658,
#  -0.006925683,
#  0.008108041,
#  0.02141363,
#  -0.0037272475,
#  -0.011398159,
#  -0.00943535,
#  -0.036859725,
#  0.005066335,
#  0.0035813875,
#  0.025123596,
#  -0.010371678,
#  0.016788628,
#  -0.0010469473,
#  0.030974898,
#  0.029512174,
#  0.019326974,
#  -0.0021743597,
#  -0.0043631485,
#  -0.00026580886,
#  -0.029205492,
#  0.031352315,
#  -0.036532875,
#  0.036357027,
#  -0.021540904,
#  0.018778617,
#  -0.026530618,
#  0.009043266,
#  -0.027146146,
#  0.021413747,
#  0.012413725,
#  0.03735953,
#  0.0039095357,
#  0.017494332,
#  0.009313073,
#  0.010322735,
#  0.015622511,
#  0.025960587,
#  0.029308278,
#  0.001772076,
#  0.019979259,
#  0.00048522427,
#  -0.009547094,
#  0.008860961,
#  0.02849613,
#  -0.016687311,
#  -0.029174918,
#  0.014040201,
#  -0.002494723,
#  0.025647866,
#  -0.0048615434,
#  -0.0062107686,
#  -0.006163883,
#  0.0211662,
#  -0.0016969009,
#  -0.015665865,
#  0.035784945,
#  -0.029975303,
#  0.01133875,
#  0.02531461,
#  0.0068372665,
#  -0.01910551,
#  0.00023405263,
#  -0.010700043,
#  0.0021079793,
#  -0.0060105277,
#  -0.004168181,
#  -0.009705785,
#  0.006045731,
#  ...]

# %%
docs_score = db.similarity_search_by_vector(embedding_vector)
docs_score
# Out:
# [Document(id='54c02e1f-55b4-4975-9ff4-5da1fa9fd1f1', metadata={'source': 'test.txt'}, page_content='The younger son of veteran Telugu actor Krishna, Mahesh Babu made his debut as a child artist in a cameo role in a Telugu film called Needa (1979), at the age of four. He went on to act as a child artist in the films Sankharavam (1987), Bazaar Rowdy, Mugguru Kodukulu (both 1988) and Gudachari 117 (1989). He played a dual role in the film Koduku Diddina Kapuram (1989). Babu then appeared in Balachandrudu and Anna Thammudu (both 1990). He made his debut as a lead actor with Rajakumarudu (1999) which won him the Nandi Award for Best Male Debut.'),
#  Document(id='37fc0556-d1ea-4ad1-944c-7ee19d7cd224', metadata={'source': 'test.txt'}, page_content="Ghattamaneni Mahesh Babu (born 9 August 1975) is an Indian actor, producer and philanthropist who works in Telugu cinema. He is one of the highest-paid actors in Indian cinema and has featured in Forbes India's Celebrity 100 list since 2012.[1][2] He has appeared in over 25 films and is a recipient of several accolades including, nine Nandi Awards, two Gaddar Telangana Film Awards, five Filmfare Awards South and four SIIMA Awards.")]

# %%
db.save_local("faiss_index")

# %%
new_db = FAISS.load_local("faiss_index",embeddings,allow_dangerous_deserialization=True)
docs = new_db.similarity_search(query)

# %%
docs
# Out:
# [Document(id='54c02e1f-55b4-4975-9ff4-5da1fa9fd1f1', metadata={'source': 'test.txt'}, page_content='The younger son of veteran Telugu actor Krishna, Mahesh Babu made his debut as a child artist in a cameo role in a Telugu film called Needa (1979), at the age of four. He went on to act as a child artist in the films Sankharavam (1987), Bazaar Rowdy, Mugguru Kodukulu (both 1988) and Gudachari 117 (1989). He played a dual role in the film Koduku Diddina Kapuram (1989). Babu then appeared in Balachandrudu and Anna Thammudu (both 1990). He made his debut as a lead actor with Rajakumarudu (1999) which won him the Nandi Award for Best Male Debut.'),
#  Document(id='37fc0556-d1ea-4ad1-944c-7ee19d7cd224', metadata={'source': 'test.txt'}, page_content="Ghattamaneni Mahesh Babu (born 9 August 1975) is an Indian actor, producer and philanthropist who works in Telugu cinema. He is one of the highest-paid actors in Indian cinema and has featured in Forbes India's Celebrity 100 list since 2012.[1][2] He has appeared in over 25 films and is a recipient of several accolades including, nine Nandi Awards, two Gaddar Telangana Film Awards, five Filmfare Awards South and four SIIMA Awards.")]

# %% [markdown]
# ### Chroma db

# %%
from langchain_chroma import Chroma
from langchain_community.document_loaders import TextLoader
from langchain_community.embeddings import OllamaEmbeddings
from langchain_text_splitters import RecursiveCharacterTextSplitter

# %%
loader = TextLoader("test.txt")
data = loader.load()
data
# Out:
# [Document(metadata={'source': 'test.txt'}, page_content="Ghattamaneni Mahesh Babu (born 9 August 1975) is an Indian actor, producer and philanthropist who works in Telugu cinema. He is one of the highest-paid actors in Indian cinema and has featured in Forbes India's Celebrity 100 list since 2012.[1][2] He has appeared in over 25 films and is a recipient of several accolades including, nine Nandi Awards, two Gaddar Telangana Film Awards, five Filmfare Awards South and four SIIMA Awards.\n\nThe younger son of veteran Telugu actor Krishna, Mahesh Babu made his debut as a child artist in a cameo role in a Telugu film called Needa (1979), at the age of four. He went on to act as a child artist in the films Sankharavam (1987), Bazaar Rowdy, Mugguru Kodukulu (both 1988) and Gudachari 117 (1989). He played a dual role in the film Koduku Diddina Kapuram (1989). Babu then appeared in Balachandrudu and Anna Thammudu (both 1990). He made his debut as a lead actor with Rajakumarudu (1999) which won him the Nandi Award for Best Male Debut.")]

# %%
text_splitter = RecursiveCharacterTextSplitter(chunk_size=500,chunk_overlap=0)
splits = text_splitter.split_documents(data)

# %%
embeddings = OllamaEmbeddings(model='llama3.2')
vectordb = Chroma.from_documents(documents=splits,embedding=embeddings )
vectordb

# %%
query = "Mahesh Babu"
docs = vectordb.similarity_search(query)

# %%
docs[0].page_content
# Out:
# 'which won him the Nandi Award for Best Male Debut.'

# %%
# Saving to the disk
vectordb = Chroma.from_documents(documents=splits,embedding=embeddings,persist_directory="./chroma_db")

# %%
# Load from disk
db2 = Chroma(persist_directory="./chroma_db",embedding_function=embeddings)
docs = db2.similarity_search(query)
print(docs[0].page_content)
# Out:
# which won him the Nandi Award for Best Male Debut.

# %%
## Similarity Search With Score
docs = vectordb.similarity_search_with_score(query)
docs
# Out:
# [(Document(id='2c9125f4-6f52-4d5d-8c92-0a61ae425cfb', metadata={'source': 'test.txt'}, page_content='which won him the Nandi Award for Best Male Debut.'),
#   6181.57470703125),
#  (Document(id='e5acbf58-f56c-4708-bc6f-fb8666ddd0f1', metadata={'source': 'test.txt'}, page_content='The younger son of veteran Telugu actor Krishna, Mahesh Babu made his debut as a child artist in a cameo role in a Telugu film called Needa (1979), at the age of four. He went on to act as a child artist in the films Sankharavam (1987), Bazaar Rowdy, Mugguru Kodukulu (both 1988) and Gudachari 117 (1989). He played a dual role in the film Koduku Diddina Kapuram (1989). Babu then appeared in Balachandrudu and Anna Thammudu (both 1990). He made his debut as a lead actor with Rajakumarudu (1999)'),
#   8332.75),
#  (Document(id='f92c32dc-cb43-4d3e-9967-971d11ebdfe5', metadata={'source': 'test.txt'}, page_content="Ghattamaneni Mahesh Babu (born 9 August 1975) is an Indian actor, producer and philanthropist who works in Telugu cinema. He is one of the highest-paid actors in Indian cinema and has featured in Forbes India's Celebrity 100 list since 2012.[1][2] He has appeared in over 25 films and is a recipient of several accolades including, nine Nandi Awards, two Gaddar Telangana Film Awards, five Filmfare Awards South and four SIIMA Awards."),
#   9019.2666015625)]

# %%
## Retriever option
retriever = vectordb.as_retriever()
retriever.invoke(query)[0].page_content
# Out:
# 'which won him the Nandi Award for Best Male Debut.'
